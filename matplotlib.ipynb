# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x=np.linspace(0,5,11)
y=x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
#plt.show it will be used in other editors other thna jupyter.
plt.xlabel('X label')
plt.ylabel('Y label')
plt.title('YoYo')
# Out:
# Text(0.5,1,'YoYo')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
fig=plot.figure()
#axes = fig.add_axes([#left,bottom,width and height ranging from 0 to 1.)
axes.plot(x,y)
axes.set_label('hello')
axes.set_label('bello')
axes.set_title("gullo")
# Out:
#   File "<ipython-input-37-774de454122a>", line 4
#     axes.set_label('hello')
#        ^
# SyntaxError: invalid syntax

# %%
fig= plt.figure()
axes= fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_title('funky')
axes.set_xlabel('shitty')
axes.set_ylabel('pitty')
# Out:
# Text(0,0.5,'pitty')

# %%
fig,axes= plt.subplots(nrows=1,ncols=2)

# %%
fig,axes= plt.subplots(nrows=1,ncols=2)
for ax in axes:
    ax.plot(x, y, 'b')

# %%
fig,axes= plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y)
axes[1].plot(y,x)
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
fig.savefig('pics.png',dpi=100)

# %%
fig = plt.figure
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-67628e967fee> in <module>()
#       1 fig = plt.figure
# ----> 2 ax = fig.add_axes([0,0,1,1])
#       3 ax.plot(x,y)
#
# AttributeError: 'function' object has no attribute 'add_axes'
